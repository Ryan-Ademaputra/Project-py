# %% [markdown]
# <a href="https://colab.research.google.com/github/Ryan-Ademaputra/Project-py/blob/main/LK1_24060125140188_Ryan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tugas Lembar Kerja 1
#
# Nama: Ryan Ademaputra
#
# NIM: 24060125140188
#
# Kelas: F

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv("/content/drive/MyDrive/Tugas_Statistika/Latihan.csv")

# %% [markdown]
# ##**#PROPERTI 1**

# %%
konstanta = 10;
tipe = "Tipe1"

mean_awal = df[tipe].mean()
median_awal = df[tipe].median()
df[tipe + "_baru"] = df[tipe] + konstanta
mean_baru = df[tipe + "_baru"].mean()
median_baru = df[tipe +"_baru"].median()

print(f"=== {tipe} ===")
print(f"Mean awal   : {mean_awal}")
print(f"Mean baru   : {mean_baru}")
print(f"Median awal : {median_awal}")
print(f"Median baru : {median_baru}")
print()
# Out:
# === Tipe1 ===
# Mean awal   : 7.839285714285714
# Mean baru   : 17.839285714285715
# Median awal : 7.0
# Median baru : 17.0

# %% [markdown]
# ##**PROPERTI 2**

# %%
konstanta = 10;
tipe = "Tipe1"

mean_awal = df[tipe].mean()
median_awal = df[tipe].median()
df[tipe + "_baru"] = df[tipe] * konstanta
mean_baru = df[tipe + "_baru"].mean()
median_baru = df[tipe +"_baru"].median()

print(f"=== {tipe} ===")
print(f"Mean awal   : {mean_awal}")
print(f"Mean baru   : {mean_baru}")
print(f"Median awal : {median_awal}")
print(f"Median baru : {median_baru}")
print()
# Out:
# === Tipe1 ===
# Mean awal   : 7.839285714285714
# Mean baru   : 78.39285714285714
# Median awal : 7.0
# Median baru : 70.0

# %% [markdown]
# ##**PROPERTI 3**

# %%
tipe = "Tipe1"
mean_awal = df[tipe].mean()
median_awal = df[tipe].median()

df_baru = pd.concat([df, pd.DataFrame({"Tipe1": [1000]})], ignore_index=True)
mean_baru = df_baru[tipe].mean()
median_baru = df_baru[tipe].median()

print(f"=== {tipe} ===")
print(f"Mean awal   : {mean_awal}")
print(f"Mean baru   : {mean_baru}")
print(f"Median awal : {median_awal}")
print(f"Median baru : {median_baru}")
print()
# Out:
# === Tipe1 ===
# Mean awal   : 7.839285714285714
# Mean baru   : 25.24561403508772
# Median awal : 7.0
# Median baru : 7.0
